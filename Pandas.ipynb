# %% [markdown]
# # pandas

# %%
import pandas as pd
data = pd.read_csv('covid_19.csv')
data
# Out:
#      Unnamed: 0      Country/Region  Confirmed Deaths  Recovered  Active  \
# 0             0         Afghanistan      36263   1269      25198    9796
# 1             1             Albania       4880    144       2745    1991
# 2             2             Algeria      27973   1163      18837    7973
# 3             3             Andorra        907     52        803      52
# 4             4              Angola        950     41        242     667
# ..          ...                 ...        ...    ...        ...     ...
# 182         182  West Bank and Gaza      10621     78       3752    6791
# 183         183      Western Sahara         10      1          8       1
# 184         184               Yemen       1691    483        833     375
# 185         185              Zambia       4552    140       2815    1597
# 186         186            Zimbabwe       2704    non        542    2126
#
#      New cases  New deaths  New recovered  Deaths / 100 Cases  \
# ...

# %%
print(data.head())
# Out:
#    Unnamed: 0 Country/Region  Confirmed Deaths  Recovered  Active  New cases  \
# 0           0    Afghanistan      36263   1269      25198    9796      106.0
# 1           1        Albania       4880    144       2745    1991      117.0
# 2           2        Algeria      27973   1163      18837    7973      616.0
# 3           3        Andorra        907     52        803      52       10.0
# 4           4         Angola        950     41        242     667       18.0
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0        10.0             18                3.50                  69.49
# 1         6.0             63                2.95                  56.25
# 2         8.0            749                4.16                  67.34
# 3         0.0              0                5.73                  88.53
# 4         1.0              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
data = pd.read_csv("covid_19.csv", index_col=0)
print(data.head())
# Out:
#   Country/Region  Confirmed Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263   1269      25198    9796      106.0        10.0
# 1        Albania       4880    144       2745    1991      117.0         6.0
# 2        Algeria      27973   1163      18837    7973      616.0         8.0
# 3        Andorra        907     52        803      52       10.0         0.0
# 4         Angola        950     41        242     667       18.0         1.0
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
data = pd.read_csv('covid_19.csv', index_col = 0)
data.index.name = "index"
data
# Out:
#            Country/Region  Confirmed Deaths  Recovered  Active  New cases  \
# index
# 0             Afghanistan      36263   1269      25198    9796      106.0
# 1                 Albania       4880    144       2745    1991      117.0
# 2                 Algeria      27973   1163      18837    7973      616.0
# 3                 Andorra        907     52        803      52       10.0
# 4                  Angola        950     41        242     667       18.0
# ...                   ...        ...    ...        ...     ...        ...
# 182    West Bank and Gaza      10621     78       3752    6791      152.0
# 183        Western Sahara         10      1          8       1        0.0
# 184                 Yemen       1691    483        833     375       10.0
# 185                Zambia       4552    140       2815    1597       71.0
# 186              Zimbabwe       2704    non        542    2126      192.0
#
# ...

# %%
import pandas as pd

def clean_column_names(data):
    """Replaces whitespace in column names with underscores."""
    data.columns = data.columns.str.replace(" ", "_", regex=True)
    return data

# Read the CSV file
data = pd.read_csv("covid_19.csv")

# Clean column names
data = clean_column_names(data)

# Display updated dataset
print(data.head(50))
# Out:
#     Unnamed:_0            Country/Region  Confirmed Deaths  Recovered  Active  \
# 0            0               Afghanistan      36263   1269      25198    9796
# 1            1                   Albania       4880    144       2745    1991
# 2            2                   Algeria      27973   1163      18837    7973
# 3            3                   Andorra        907     52        803      52
# 4            4                    Angola        950     41        242     667
# 5            5       Antigua and Barbuda         86      3         65      18
# 6            6                 Argentina     167416   3059      72575   91782
# 7            7                   Armenia      37390    711      26665   10014
# 8            8                 Australia      15303    167       9311    5825
# 9            9                   Austria      20558    713      18246    1599
# 10          10                Azerbaijan      30446    423      23242    6781
# ...

# %%
# Display basic information
print("Column Names:", data.columns.tolist())
print("\nData Types:")
print(data.dtypes)
print("\nMissing Values:")
print(data.isnull().sum())

# Display updated dataset
print(data.head())
# Out:
# Column Names: ['Unnamed:_0', 'Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'New_cases', 'New_deaths', 'New_recovered', 'Deaths_/_100_Cases', 'Recovered_/_100_Cases', 'Deaths_/_100_Recovered', 'Confirmed_last_week', '1_week_change', '1_week_%_increase', 'WHO_Region']
#
# Data Types:
# Unnamed:_0                  int64
# Country/Region             object
# Confirmed                   int64
# Deaths                     object
# Recovered                   int64
# Active                      int64
# New_cases                 float64
# New_deaths                float64
# New_recovered               int64
# Deaths_/_100_Cases        float64
# Recovered_/_100_Cases     float64
# Deaths_/_100_Recovered    float64
# Confirmed_last_week         int64
# 1_week_change               int64
# 1_week_%_increase         float64
# WHO_Region                 object
# dtype: object
#
# Missing Values:
# Unnamed:_0                 0
# Country/Region             0
# ...

# %%
def fill_missing_values(data):
    """Fills NaN values with the mean of the respective column."""
    data.fillna(data.mean(numeric_only=True), inplace=True)
    return data
data = fill_missing_values(data)
data
# Out:
#      Unnamed:_0      Country/Region  Confirmed Deaths  Recovered  Active  \
# 0             0         Afghanistan      36263   1269      25198    9796
# 1             1             Albania       4880    144       2745    1991
# 2             2             Algeria      27973   1163      18837    7973
# 3             3             Andorra        907     52        803      52
# 4             4              Angola        950     41        242     667
# ..          ...                 ...        ...    ...        ...     ...
# 182         182  West Bank and Gaza      10621     78       3752    6791
# 183         183      Western Sahara         10      1          8       1
# 184         184               Yemen       1691    483        833     375
# 185         185              Zambia       4552    140       2815    1597
# 186         186            Zimbabwe       2704    non        542    2126
#
#      New_cases  New_deaths  New_recovered  Deaths_/_100_Cases  \
# ...

# %%
# Count the number of unique countries
num_unique_countries = data["Country/Region"].nunique()

print(f"Number of unique countries: {num_unique_countries}")
# Out:
# Number of unique countries: 187

# %%
# Check for duplicate country entries
duplicate_countries = data.duplicated(subset=['Country/Region'])

# Display duplicate entries
print(data[duplicate_countries])
# Out:
# Empty DataFrame
# Columns: [Unnamed:_0, Country/Region, Confirmed, Deaths, Recovered, Active, New_cases, New_deaths, New_recovered, Deaths_/_100_Cases, Recovered_/_100_Cases, Deaths_/_100_Recovered, Confirmed_last_week, 1_week_change, 1_week_%_increase, WHO_Region]
# Index: []

# %%
# Calculate statistics for 'Total Cases'
mean_cases = df["Confirmed"].mean()
median_cases = df["Confirmed"].median()
std_cases = df["Confirmed"].std()

# Print the results
print(f"Mean of Total Cases: {mean_cases}")
print(f"Median of Total Cases: {median_cases}")
print(f"Standard Deviation of Total Cases: {std_cases}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 # Calculate statistics for 'Total Cases'
# ----> 2 mean_cases = df["Confirmed"].mean()
#       3 median_cases = df["Confirmed"].median()
#       4 std_cases = df["Confirmed"].std()
#
# NameError: name 'df' is not defined

# %%
    # Convert 'Deaths' to numeric, forcing errors to NaN (non-numeric values become NaN)
    data["Deaths"] = pd.to_numeric(data["Deaths"], errors="coerce")

    # Calculate mean of the 'Deaths' column, ignoring NaN values
    mean_deaths = data["Deaths"].mean()

    # Replace NaN values (previously non-numeric strings) with mean
    data["Deaths"].fillna(mean_deaths, inplace=True)

# Display updated dataset
print(data.head(10))
# Out:
#    Unnamed:_0       Country/Region  Confirmed  Deaths  Recovered  Active  \
# 0           0          Afghanistan      36263  1269.0      25198    9796
# 1           1              Albania       4880   144.0       2745    1991
# 2           2              Algeria      27973  1163.0      18837    7973
# 3           3              Andorra        907    52.0        803      52
# 4           4               Angola        950    41.0        242     667
# 5           5  Antigua and Barbuda         86     3.0         65      18
# 6           6            Argentina     167416  3059.0      72575   91782
# 7           7              Armenia      37390   711.0      26665   10014
# 8           8            Australia      15303   167.0       9311    5825
# 9           9              Austria      20558   713.0      18246    1599
#
#    New_cases  New_deaths  New_recovered  Deaths_/_100_Cases  \
# 0      106.0        10.0             18                3.50
# ...

# %%
data['Deaths'] = pd.to_numeric(data['Deaths'], errors='coerce')
print(data['Deaths'].dtypes)
# Out:
# float64

# %%
# Calculate total deaths and recoveries
total_deaths = data['Deaths'].sum()
total_recoveries = data['Recovered'].sum()

print("Total Deaths:", total_deaths)
print("Total Recoveries:", total_recoveries)
# Out:
# Total Deaths: 657516.1290322581
# Total Recoveries: 9468087

# %%
# Filter countries with more than 1 million cases
high_case_countries = data[data['Confirmed'] > 1_000_000]

# Count the number of such countries
num_countries = high_case_countries.shape[0]

print("Number of countries with more than 1 million cases:", num_countries)
# Out:
# Number of countries with more than 1 million cases: 3

# %%
# Calculate Recovery Rate (Recovered / Total Cases)
data['Recovery_Rate'] = (data['Recovered'] / data['Confirmed']) * 100

# Filter countries with Recovery Rate above 95%
high_recovery_countries = data[data['Recovery_Rate'] > 95]

# Display the result
print(high_recovery_countries[['Country/Region', 'Recovery_Rate']])
# Out:
#     Country/Region  Recovery_Rate
# 24          Brunei      97.872340
# 48        Djibouti      98.379126
# 49        Dominica     100.000000
# 69         Grenada     100.000000
# 75        Holy See     100.000000
# 78         Iceland      98.327940
# 105       Malaysia      96.597035
# 110      Mauritius      96.511628
# 121    New Zealand      97.238279
# 126         Norway      95.838809
# 136          Qatar      97.017254
# 164        Taiwan*      95.238095

# %%
print("Column names:", data.columns)
# Out:
# Column names: Index(['Unnamed:_0', 'Country/Region', 'Confirmed', 'Deaths', 'Recovered',
#        'Active', 'New_cases', 'New_deaths', 'New_recovered',
#        'Deaths_/_100_Cases', 'Recovered_/_100_Cases', 'Deaths_/_100_Recovered',
#        'Confirmed_last_week', '1_week_change', '1_week_%_increase',
#        'WHO_Region', 'Recovery_Rate'],
#       dtype='object')

# %%
data.drop(columns=['WHO_Region', 'Confirmed'], inplace=True)
data
# Out:
#      Unnamed:_0      Country/Region       Deaths  Recovered  Active  \
# 0             0         Afghanistan  1269.000000      25198    9796
# 1             1             Albania   144.000000       2745    1991
# 2             2             Algeria  1163.000000      18837    7973
# 3             3             Andorra    52.000000        803      52
# 4             4              Angola    41.000000        242     667
# ..          ...                 ...          ...        ...     ...
# 182         182  West Bank and Gaza    78.000000       3752    6791
# 183         183      Western Sahara     1.000000          8       1
# 184         184               Yemen   483.000000        833     375
# 185         185              Zambia   140.000000       2815    1597
# 186         186            Zimbabwe  3516.129032        542    2126
#
#      New_cases  New_deaths  New_recovered  Deaths_/_100_Cases  \
# 0        106.0        10.0             18                3.50
# ...

# %%
# Find the country with the maximum deaths
max_deaths_country = data.loc[data['Deaths'].idxmax()]

print("Country with the maximum deaths:")
print(max_deaths_country['Country/Region'], "with", max_deaths_country['Deaths'], "deaths")
# Out:
# Country with the maximum deaths:
# US with 148011.0 deaths

# %%
# Sort countries by deaths in descending order
df_sorted = data.sort_values(by='Deaths', ascending=False)

print("Countries sorted by deaths (descending order):")
print(df_sorted[['Country/Region', 'Deaths']])
# Out:
# Countries sorted by deaths (descending order):
#        Country/Region    Deaths
# 173                US  148011.0
# 23             Brazil   87618.0
# 177    United Kingdom   45844.0
# 111            Mexico   44022.0
# 85              Italy   35112.0
# ..                ...       ...
# 19             Bhutan       0.0
# 130  Papua New Guinea       0.0
# 75           Holy See       0.0
# 30           Cambodia       0.0
# 114          Mongolia       0.0
#
# [187 rows x 2 columns]

# %%
# Create new column 'Total_Cases' by summing 'Deaths', 'Recovered', and 'Active'
data['Total_Cases'] = data['Deaths'] + data['Recovered'] + data['Active']

print(data[['Country/Region', 'Deaths', 'Recovered', 'Active', 'Total_Cases']])
# Out:
#          Country/Region       Deaths  Recovered  Active   Total_Cases
# 0           Afghanistan  1269.000000      25198    9796  36263.000000
# 1               Albania   144.000000       2745    1991   4880.000000
# 2               Algeria  1163.000000      18837    7973  27973.000000
# 3               Andorra    52.000000        803      52    907.000000
# 4                Angola    41.000000        242     667    950.000000
# ..                  ...          ...        ...     ...           ...
# 182  West Bank and Gaza    78.000000       3752    6791  10621.000000
# 183      Western Sahara     1.000000          8       1     10.000000
# 184               Yemen   483.000000        833     375   1691.000000
# 185              Zambia   140.000000       2815    1597   4552.000000
# 186            Zimbabwe  3516.129032        542    2126   6184.129032
#
# [187 rows x 5 columns]

# %%
# Create new column 'Total_Cases' by summing 'Deaths', 'Recovered', and 'Active'
data['Total_Cases'] = data['Deaths'] + data['Recovered'] + data['Active']

# Calculate 'Death_Rate' and store it in a new column
data['Death_Rate'] = (data['Deaths'] / data['Total_Cases']) * 100

print(data[['Country/Region', 'Deaths', 'Total_Cases', 'Death_Rate']])
# Out:
#          Country/Region       Deaths   Total_Cases  Death_Rate
# 0           Afghanistan  1269.000000  36263.000000    3.499435
# 1               Albania   144.000000   4880.000000    2.950820
# 2               Algeria  1163.000000  27973.000000    4.157581
# 3               Andorra    52.000000    907.000000    5.733186
# 4                Angola    41.000000    950.000000    4.315789
# ..                  ...          ...           ...         ...
# 182  West Bank and Gaza    78.000000  10621.000000    0.734394
# 183      Western Sahara     1.000000     10.000000   10.000000
# 184               Yemen   483.000000   1691.000000   28.562980
# 185              Zambia   140.000000   4552.000000    3.075571
# 186            Zimbabwe  3516.129032   6184.129032   56.857304
#
# [187 rows x 4 columns]

# %%
# Create new column 'Total_Cases' by summing 'Deaths', 'Recovered', and 'Active'
data['Total_Cases'] = data['Deaths'] + data['Recovered'] + data['Active']

# Calculate 'Death_Rate' and store it in a new column
data['Death_Rate'] = (data['Deaths'] / data['Total_Cases']) * 100

# Define a threshold for low death rate (e.g., less than 5%)
low_death_rate_threshold = 5

# Filter countries where total cases are high and death rate is low
# (You can adjust the condition for 'Total_Cases' based on your dataset's size)
filtered_countries = data[(data['Death_Rate'] < low_death_rate_threshold) & (data['Total_Cases'] > 1000000)]

# Display the result
print(filtered_countries[['Country/Region', 'Total_Cases', 'Death_Rate']])
# Out:
#     Country/Region  Total_Cases  Death_Rate
# 23          Brazil    2442375.0    3.587410
# 79           India    1480073.0    2.257186
# 173             US    4290259.0    3.449932

# %%
# Print head of only the selected columns
print(data[['Country/Region', 'Death_Rate']].head())
# Out:
#   Country/Region  Death_Rate
# 0    Afghanistan    3.499435
# 1        Albania    2.950820
# 2        Algeria    4.157581
# 3        Andorra    5.733186
# 4         Angola    4.315789

# %%
import pandas as pd
data = pd.read_csv('covid_19.csv')
import matplotlib.pyplot as plt
# Create scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(data['Confirmed'], data['Deaths'], color='blue', alpha=0.6, edgecolors='black')

# Labels and title
plt.xlabel('Confirmed')
plt.ylabel('Deaths')
plt.title('Total Cases vs Total Deaths')

# Show grid for better readability
plt.grid(True, linestyle='--', alpha=0.7)

# Show plot
plt.show()

# %%
# Save DataFrame as CSV
data.to_csv('covid_data.csv', index=False)

print("Dataset saved as 'covid_data.csv'.")
# Out:
# Dataset saved as 'covid_data.csv'.
